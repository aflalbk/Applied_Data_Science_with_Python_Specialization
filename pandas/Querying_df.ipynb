# %%
import pandas as pd

# %%
df = pd.read_csv('Admission_Predict.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
# convert Serial number = index number
df = pd.read_csv('Admission_Predict.csv', index_col=0)
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
new_df = df.rename(columns = {'SOP' : 'Statement of Purpose', 'LOR ' : 'Letter of recommendation'})

# %%
new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             Letter of recommendation  CGPA  Research  Chance of Admit
# Serial No.
# 1                                4.5  9.65         1              0.92
# 2                                4.5  8.87         1              0.76
# 3                                3.5  8.00         1              0.72
# 4                                2.5  8.67         1              0.80
# 5                                3.0  8.21         0              0.65

# %% [markdown]
# To remove whitespace in the column name. we use `df.rename(mapper=str.strip, axis = 'column' `.

# %%
new_df = new_df.rename(mapper=str.strip, axis='columns')
new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             Letter of recommendation  CGPA  Research  Chance of Admit
# Serial No.
# 1                                4.5  9.65         1             0.92
# 2                                4.5  8.87         1             0.76
# 3                                3.5  8.00         1             0.72
# 4                                2.5  8.67         1             0.80
# 5                                3.0  8.21         0             0.65

# %%
new_df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'Statement of Purpose',
#        'Letter of recommendation', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %%
new_df.columns[3]
# Out:
# 'Statement of Purpose'

# %%
new_df.columns[3].lower().strip()
# Out:
# 'statement of purpose'

# %%
# let's make all column name into lower case.

col_lst = list(new_df.columns)
cols = [x.lower().strip() for x in col_lst]
new_df.columns = cols
new_df.columns
# Out:
# Index(['gre score', 'toefl score', 'university rating', 'statement of purpose',
#        'letter of recommendation', 'cgpa', 'research', 'chance of admit'],
#       dtype='object')

# %%
new_df.head()
# Out:
#             gre score  toefl score  university rating  statement of purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             letter of recommendation  cgpa  research  chance of admit
# Serial No.
# 1                                4.5  9.65         1             0.92
# 2                                4.5  8.87         1             0.76
# 3                                3.5  8.00         1             0.72
# 4                                2.5  8.67         1             0.80
# 5                                3.0  8.21         0             0.65

# %%
# chance of admiti is >7.

admit_mask = new_df['chance of admit']>0.7
admit_mask
# Out:
# Serial No.
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398     True
# 399    False
# 400     True
# Name: chance of admit, Length: 400, dtype: bool

# %%
new_df.where(admit_mask).head()
# Out:
#             gre score  toefl score  university rating  statement of purpose  \
# Serial No.
# 1               337.0        118.0                4.0                   4.5
# 2               324.0        107.0                4.0                   4.0
# 3               316.0        104.0                3.0                   3.0
# 4               322.0        110.0                3.0                   3.5
# 5                 NaN          NaN                NaN                   NaN
#
#             letter of recommendation  cgpa  research  chance of admit
# Serial No.
# 1                                4.5  9.65       1.0             0.92
# 2                                4.5  8.87       1.0             0.76
# 3                                3.5  8.00       1.0             0.72
# 4                                2.5  8.67       1.0             0.80
# 5                                NaN   NaN       NaN              NaN

# %% [markdown]
# to remove NaN we can use `.dropna()`

# %%
new_df.where(admit_mask).dropna().head()
# Out:
#             gre score  toefl score  university rating  statement of purpose  \
# Serial No.
# 1               337.0        118.0                4.0                   4.5
# 2               324.0        107.0                4.0                   4.0
# 3               316.0        104.0                3.0                   3.0
# 4               322.0        110.0                3.0                   3.5
# 6               330.0        115.0                5.0                   4.5
#
#             letter of recommendation  cgpa  research  chance of admit
# Serial No.
# 1                                4.5  9.65       1.0             0.92
# 2                                4.5  8.87       1.0             0.76
# 3                                3.5  8.00       1.0             0.72
# 4                                2.5  8.67       1.0             0.80
# 6                                3.0  9.34       1.0             0.90

# %%
# simplified version 
new_df[new_df['chance of admit']>0.7].head()
# Out:
#             gre score  toefl score  university rating  statement of purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 6                 330          115                  5                   4.5
#
#             letter of recommendation  cgpa  research  chance of admit
# Serial No.
# 1                                4.5  9.65         1             0.92
# 2                                4.5  8.87         1             0.76
# 3                                3.5  8.00         1             0.72
# 4                                2.5  8.67         1             0.80
# 6                                3.0  9.34         1             0.90

# %%
new_df['gre score'].head()
# Out:
# Serial No.
# 1    337
# 2    324
# 3    316
# 4    322
# 5    314
# Name: gre score, dtype: int64

# %%
new_df[['gre score','cgpa','chance of admit']].head()
# Out:
#             gre score  cgpa  chance of admit
# Serial No.
# 1                 337  9.65             0.92
# 2                 324  8.87             0.76
# 3                 316  8.00             0.72
# 4                 322  8.67             0.80
# 5                 314  8.21             0.65

# %%
(new_df['chance of admit']>0.7) & (new_df['chance of admit']<0.9)
# Out:
# Serial No.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
new_df['chance of admit'].gt(0.7) & new_df['chance of admit'].lt(0.9)
# Out:
# Serial No.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
new_df[(new_df['chance of admit']>0.7) & (new_df['chance of admit']<0.9)].head()
# Out:
#             gre score  toefl score  university rating  statement of purpose  \
# Serial No.
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 7                 321          109                  3                   3.0
# 12                327          111                  4                   4.0
#
#             letter of recommendation  cgpa  research  chance of admit
# Serial No.
# 2                                4.5  8.87         1             0.76
# 3                                3.5  8.00         1             0.72
# 4                                2.5  8.67         1             0.80
# 7                                4.0  8.20         1             0.75
# 12                               4.5  9.00         1             0.84

# %%
new_df['serial no'] = new_df.index
new_df.head()
# Out:
#             gre score  toefl score  university rating  statement of purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             letter of recommendation  cgpa  research  chance of admit  \
# Serial No.
# 1                                4.5  9.65         1             0.92
# 2                                4.5  8.87         1             0.76
# 3                                3.5  8.00         1             0.72
# 4                                2.5  8.67         1             0.80
# 5                                3.0  8.21         0             0.65
#
#             serial no
# Serial No.
# 1                   1
# ...

# %%
new_df = new_df.reset_index()
new_df.head()
# Out:
#    Serial No.  gre score  toefl score  university rating  \
# 0           1        337          118                  4
# 1           2        324          107                  4
# 2           3        316          104                  3
# 3           4        322          110                  3
# 4           5        314          103                  2
#
#    statement of purpose  letter of recommendation  cgpa  research  \
# 0                   4.5                       4.5  9.65         1
# 1                   4.0                       4.5  8.87         1
# 2                   3.0                       3.5  8.00         1
# 3                   3.5                       2.5  8.67         1
# 4                   2.0                       3.0  8.21         0
#
#    chance of admit  serial no
# 0             0.92          1
# 1             0.76          2
# 2             0.72          3
# 3             0.80          4
# 4             0.65          5

# %%
new_df = new_df.set_index('chance of admit')
new_df.head()
# Out:
#                  Serial No.  gre score  toefl score  university rating  \
# chance of admit
# 0.92                      1        337          118                  4
# 0.76                      2        324          107                  4
# 0.72                      3        316          104                  3
# 0.80                      4        322          110                  3
# 0.65                      5        314          103                  2
#
#                  statement of purpose  letter of recommendation  cgpa  \
# chance of admit
# 0.92                              4.5                       4.5  9.65
# 0.76                              4.0                       4.5  8.87
# 0.72                              3.0                       3.5  8.00
# 0.80                              3.5                       2.5  8.67
# 0.65                              2.0                       3.0  8.21
#
#                  research  serial no
# chance of admit
# ...

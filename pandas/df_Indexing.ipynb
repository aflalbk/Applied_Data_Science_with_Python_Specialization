# %%
import pandas as pd

# %%
df = pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %% [markdown]
# Find unique value in a column `.unique()`

# %%
df['SUMLEV'].unique()
# Out:
# array([40, 50], dtype=int64)

# %%
df.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'NPOPCHG_2010', 'NPOPCHG_2011',
#        'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015',
#        'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014',
#        'BIRTHS2015', 'DEATHS2010', 'DEATHS2011', 'DEATHS2012', 'DEATHS2013',
#        'DEATHS2014', 'DEATHS2015', 'NATURALINC2010', 'NATURALINC2011',
#        'NATURALINC2012', 'NATURALINC2013', 'NATURALINC2014', 'NATURALINC2015',
#        'INTERNATIONALMIG2010', 'INTERNATIONALMIG2011', 'INTERNATIONALMIG2012',
#        'INTERNATIONALMIG2013', 'INTERNATIONALMIG2014', 'INTERNATIONALMIG2015',
#        'DOMESTICMIG2010', 'DOMESTICMIG2011', 'DOMESTICMIG2012',
#        'DOMESTICMIG2013', 'DOMESTICMIG2014', 'DOMESTICMIG2015', 'NETMIG2010',
# ...

# %%
# lets reduce size of a data frame

column_selecting = ['STNAME', 'CTYNAME','BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014','BIRTHS2015',
                    'POPESTIMATE2010','POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013','POPESTIMATE2014', 'POPESTIMATE2015']
df = df[column_selecting]
df.head()
# Out:
#     STNAME         CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# 0  Alabama         Alabama       14226       59689       59062       57938
# 1  Alabama  Autauga County         151         636         615         574
# 2  Alabama  Baldwin County         517        2187        2092        2160
# 3  Alabama  Barbour County          70         335         300         283
# 4  Alabama     Bibb County          44         266         245         259
#
#    BIRTHS2014  BIRTHS2015  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0       58334       58305          4785161          4801108          4816089
# 1         623         600            54660            55253            55175
# 2        2186        2240           183193           186659           190396
# 3         260         269            27341            27226            27159
# 4         247         253            22861            22733            22642
#
# ...

# %%
# set 'STNAME' and 'CTYNAME' as combination of index value. 

df = df.set_index(['STNAME','CTYNAME'])
df.head()
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Alabama              14226       59689       59062       57938
#         Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#         Barbour County          70         335         300         283
#         Bibb County             44         266         245         259
#
#                         BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Alabama              58334       58305          4785161
#         Autauga County         623         600            54660
#         Baldwin County        2186        2240           183193
#         Barbour County         260         269            27341
#         Bibb County            247         253            22861
#
#                         POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME  CTYNAME
# ...

# %%
df.loc['Alabama','Bibb County']
# Out:
# C:\Users\aflal\AppData\Local\Temp\ipykernel_23064\134654613.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc['Alabama','Bibb County']
#                      BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Bibb County          44         266         245         259
#
#                      BIRTHS2014  BIRTHS2015  POPESTIMATE2010  POPESTIMATE2011  \
# STNAME  CTYNAME
# Alabama Bibb County         247         253            22861            22733
#
#                      POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# STNAME  CTYNAME
# Alabama Bibb County            22642            22512            22549
#
#                      POPESTIMATE2015
# STNAME  CTYNAME
# Alabama Bibb County            22583

# %%
df.loc[[('Alabama','Bibb County'),('Alabama','Baldwin County')]]
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Bibb County             44         266         245         259
#         Baldwin County         517        2187        2092        2160
#
#                         BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Bibb County            247         253            22861
#         Baldwin County        2186        2240           183193
#
#                         POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME  CTYNAME
# Alabama Bibb County               22733            22642            22512
#         Baldwin County           186659           190396           195126
#
#                         POPESTIMATE2014  POPESTIMATE2015
# STNAME  CTYNAME
# Alabama Bibb County               22549            22583
#         Baldwin County           199713           203709

# %%
df.loc[[['Alabama','Bibb County'],['Alabama','Baldwin County']]]
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Bibb County             44         266         245         259
#         Baldwin County         517        2187        2092        2160
#
#                         BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Bibb County            247         253            22861
#         Baldwin County        2186        2240           183193
#
#                         POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME  CTYNAME
# Alabama Bibb County               22733            22642            22512
#         Baldwin County           186659           190396           195126
#
#                         POPESTIMATE2014  POPESTIMATE2015
# STNAME  CTYNAME
# Alabama Bibb County               22549            22583
#         Baldwin County           199713           203709
